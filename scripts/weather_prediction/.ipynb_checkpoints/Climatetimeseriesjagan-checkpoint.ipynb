# %%
from dateutil.parser import parse 
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
plt.rcParams.update({'figure.figsize': (10, 7), 'figure.dpi': 120})

# Import as Dataframe
df = pd.read_csv('FinalCleanData.csv', parse_dates=['date'])
df.head()
# Out:
#         date  meantempm  maxtempm  mintempm  meantempm_1  meantempm_2  \
# 0 2016-04-05         34        41        27           35           36
# 1 2016-05-05         31        38        24           34           35
# 2 2016-06-05         28        34        21           31           34
# 3 2016-07-05         30        38        23           28           31
# 4 2016-08-05         34        41        26           30           28
#
#    meantempm_3  meandewptm_1  meandewptm_2  meandewptm_3    ...      \
# 0           34             6             4            -1    ...
# 1           36             7             6             4    ...
# 2           35            11             7             6    ...
# 3           34            13            11             7    ...
# 4           31            10            13            11    ...
#
#    mindewptm_3  maxpressurem_1  maxpressurem_2  maxpressurem_3  \
# 0          -10            1009            1008            1009
# ...

# %%
# Time series data source: fpp pacakge in R.
import matplotlib.pyplot as plt
df = pd.read_csv('FinalCleanData.csv', parse_dates=['date'], index_col='date')
# Draw Plot
def plot_df(df, x, y, title="", xlabel='Date', ylabel='maxtempm', dpi=100):
    plt.figure(figsize=(16,5), dpi=dpi)
    plt.plot(x, y, color='tab:red')
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.show()

plot_df(df, x=df.index, y=df.maxtempm, title='Mean Temperature.')

# %%
# Import data
df = pd.read_csv('FinalCleanData.csv', parse_dates=['date'])
x = df['date'].values
y1 = df['maxtempm'].values

# Plot
fig, ax = plt.subplots(1, 1, figsize=(16,5), dpi= 120)
plt.fill_between(x, y1=y1, y2=-y1, alpha=0.5, linewidth=2, color='seagreen')
plt.ylim(-70, 70)
plt.title('Air Passengers (Two Side View)', fontsize=16)
plt.hlines(y=0, xmin=np.min(df.date), xmax=np.max(df.date), linewidth=.5)
plt.show()

# %%
df.index[0:10]
# Out:
# DatetimeIndex(['2016-04-05', '2016-05-05', '2016-06-05', '2016-07-05',
#                '2016-08-05', '2016-09-05', '2016-10-05', '2016-11-05',
#                '2016-12-05', '2016-05-13'],
#               dtype='datetime64[ns]', name='date', freq=None)

# %%
df.index[0:10]

# %%
df["date"]=df.index
df.dtypes
# Out:
# meantempm                   int64
# maxtempm                    int64
# mintempm                    int64
# meantempm_1                 int64
# meantempm_2                 int64
# meantempm_3                 int64
# meandewptm_1                int64
# meandewptm_2                int64
# meandewptm_3                int64
# meanpressurem_1           float64
# meanpressurem_2           float64
# meanpressurem_3           float64
# maxhumidity_1               int64
# maxhumidity_2               int64
# maxhumidity_3               int64
# minhumidity_1               int64
# minhumidity_2               int64
# minhumidity_3               int64
# maxtempm_1                  int64
# maxtempm_2                  int64
# maxtempm_3                  int64
# mintempm_1                  int64
# mintempm_2                  int64
# mintempm_3                  int64
# maxdewptm_1                 int64
# maxdewptm_2                 int64
# maxdewptm_3                 int64
# ...

# %%
# Import Data
df = pd.read_csv('FinalCleanData.csv', parse_dates=['date'], index_col='date')
df.reset_index(inplace=True)

# Prepare data
df['year'] = [d.year for d in df.date]
df['month'] = [d.strftime('%b') for d in df.date]
years = df['year'].unique()

# Prep Colors
np.random.seed(100)
mycolors = np.random.choice(list(mpl.colors.XKCD_COLORS.keys()), len(years), replace=False)

# Draw Plot
plt.figure(figsize=(16,12), dpi= 80)
for i, y in enumerate(years):
    if i > 0:        
        plt.plot('month', 'meantempm', data=df.loc[df.year==y, :], color=mycolors[i], label=y)
        plt.text(df.loc[df.year==y, :].shape[0]-.9, df.loc[df.year==y, 'meantempm'][-1:].values[0], y, fontsize=12, color=mycolors[i])

# Decoration
plt.gca().set(xlim=(-0.3, 11), ylim=(2, 30), ylabel='$Drug Sales$', xlabel='$Month$')
plt.yticks(fontsize=12, alpha=.7)
plt.title("Seasonal Mean Temperature Time Series", fontsize=20)
plt.show()

# %%
# Import Data
df = pd.read_csv('FinalCleanData.csv', parse_dates=['date'], index_col='date')
df.reset_index(inplace=True)

# Prepare data
df['year'] = [d.year for d in df.date]
df['month'] = [d.strftime('%b') for d in df.date]
years = df['year'].unique()

# Draw Plot
fig, axes = plt.subplots(1, 2, figsize=(20,7), dpi= 80)
sns.boxplot(x='year', y='meantempm', data=df, ax=axes[0])
sns.boxplot(x='month', y='meantempm', data=df.loc[~df.year.isin([1991, 2008]), :])

# Set Title
axes[0].set_title('Year-wise Box Plot\n(The Trend)', fontsize=18); 
axes[1].set_title('Month-wise Box Plot\n(The Seasonality)', fontsize=18)
plt.show()

# %%
fig, axes = plt.subplots(1,3, figsize=(20,4), dpi=100)
pd.read_csv('FinalCleanData.csv', parse_dates=['date'], index_col='date').plot(title='Trend Only', legend=False, ax=axes[0])

pd.read_csv('FinalCleanData.csv', parse_dates=['date'], index_col='date').plot(title='Seasonality Only', legend=False, ax=axes[1])

pd.read_csv('FinalCleanData.csv', parse_dates=['date'], index_col='date').plot(title='Trend and Seasonality', legend=False, ax=axes[2])

# %%
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

df = pd.read_csv('FinalCleanData.csv')

# Calculate ACF and PACF upto 50 lags
# acf_50 = acf(df.value, nlags=50)
# pacf_50 = pacf(df.value, nlags=50)

# Draw Plot
fig, axes = plt.subplots(1,2,figsize=(16,3), dpi= 100)
plot_acf(df.value.tolist(), lags=50, ax=axes[0])
plot_pacf(df.value.tolist(), lags=50, ax=axes[1])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-eed196670274> in <module>
#      10 # Draw Plot
#      11 fig, axes = plt.subplots(1,2,figsize=(16,3), dpi= 100)
# ---> 12 plot_acf(df.value.tolist(), lags=50, ax=axes[0])
#      13 plot_pacf(df.value.tolist(), lags=50, ax=axes[1])
#
# C:\Anaconda\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'value'

# %%
from pandas import Series
from matplotlib import pyplot
df = pd.read_csv('FinalCleanData.csv', parse_dates=['date'], index_col='date')
series = pd.Series(df["maxtempm"],index=df.index)
#print(series)
series.plot()
pyplot.xlabel('Date', fontsize=18)
pyplot.ylabel('MaxTempM', fontsize=16)
pyplot.title('Date vs MaxTemp', fontsize=16)
pyplot.show()

# %%
df[["maxtempm","meantempm"]].values
# Out:
# array([[41, 34],
#        [38, 31],
#        [34, 28],
#        ...,
#        [33, 26],
#        [34, 26],
#        [34, 26]])
